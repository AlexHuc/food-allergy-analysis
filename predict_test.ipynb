# %% [markdown]
# # Flask Service Testing Notebook
#
# This notebook is used to test the Flask service that serves the machine learning models.
# Before running the cells below, make sure to start the prediction service by executing the following command in your terminal:
#
# ```bash
# python predict.py
# ```

# %%
import requests

# %%
url = "http://localhost:9696/predict"

# %%
patient = {
    "BIRTH_YEAR": 2015,
    "GENDER_FACTOR": "M",
    "RACE_FACTOR": "African American",
    "ETHNICITY_FACTOR": "Non-Hispanic",
    "PAYER_FACTOR": "Non-Medicaid",
    "NUM_ALLERGIES": 2
}

# %%
requests.post(url, json=patient).json()
# Out:
# {'error': 'Cannot predict asthma risk. Missing required patient information.',
#  'missing_features': ['ATOPIC_MARCH_COHORT', 'AGE_START_YEARS']}

# %%
patient = {
    "BIRTH_YEAR": 2015,
    "GENDER_FACTOR": "M",
    "RACE_FACTOR": "African American",
    "ETHNICITY_FACTOR": "Non-Hispanic",
    "PAYER_FACTOR": "Non-Medicaid",
    "ATOPIC_MARCH_COHORT": True,
    "AGE_START_YEARS": 6,
    "NUM_ALLERGIES": 2
}

# %%
requests.post(url, json=patient).json()
# Out:
# {'asthma': True,
#  'asthma_probability': 0.6527391076087952,
#  'missing_features': ['SHELLFISH_ALG_START',
#   'FISH_ALG_START',
#   'MILK_ALG_START',
#   'SOY_ALG_START',
#   'EGG_ALG_START',
#   'WHEAT_ALG_START',
#   'PEANUT_ALG_START',
#   'SESAME_ALG_START',
#   'TREENUT_ALG_START',
#   'WALNUT_ALG_START',
#   'PECAN_ALG_START',
#   'PISTACH_ALG_START',
#   'ALMOND_ALG_START',
#   'BRAZIL_ALG_START',
#   'HAZELNUT_ALG_START',
#   'CASHEW_ALG_START',
#   'ATOPIC_DERM_START',
#   'ALLERGIC_RHINITIS_START'],
#  'warning': 'Patient is at risk for asthma, but asthma start age cannot be predicted reliably. Missing allergy and condition history data required for age prediction.'}

# %%
patient = {
    "BIRTH_YEAR": 2015,
    "GENDER_FACTOR": "M",
    "RACE_FACTOR": "African American",
    "ETHNICITY_FACTOR": "Non-Hispanic",
    "PAYER_FACTOR": "Non-Medicaid",
    "ATOPIC_MARCH_COHORT": True,
    "AGE_START_YEARS": 3.5,
    "NUM_ALLERGIES": 2,
    "SHELLFISH_ALG_START": None,
    "FISH_ALG_START": None,
    "MILK_ALG_START": 16.5,
    "SOY_ALG_START": None,
    "EGG_ALG_START": 8.5,
    "WHEAT_ALG_START": None,
    "PEANUT_ALG_START": None,
    "SESAME_ALG_START": None,
    "TREENUT_ALG_START": None,
    "WALNUT_ALG_START": None,
    "PECAN_ALG_START": None,
    "PISTACH_ALG_START": None,
    "ALMOND_ALG_START": None,
    "BRAZIL_ALG_START": None,
    "HAZELNUT_ALG_START": None,
    "CASHEW_ALG_START": None,
    "ATOPIC_DERM_START": 21.0,
    "ALLERGIC_RHINITIS_START": None
}

# %%
requests.post(url, json=patient).json()
# Out:
# {'asthma': True,
#  'asthma_probability': 0.6178941130638123,
#  'asthma_start_age_predicted': 4.292960166931152}
